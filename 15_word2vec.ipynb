# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sys

# %% [markdown]
# # word2vec
#
# 나중에 하자. 지금은 스킵!

# %% [markdown]
# matplotlib에서 한글을 표시하기 위한 설정은 아래와 같이 합니다.

# %%
reload(sys)
sys.setdefaultencoding('utf-8')

# %%
sentences = ["나 고양이 좋다",
             "나 강아지 좋다",
             "나 동물 좋다",
             "강아지 고양이 동물",
             "여자친구 고양이 강아지 좋다",
             "고양이 생선 우유 좋다",
             "강아지 생선 싫다 우유 좋다",
             "강아지 고양이 눈 좋다",
             "나 여자친구 좋다",
             "여자친구 나 싫다",
             "여자친구 나 영화 책 음악 좋다",
             "나 게임 만화 애니 좋다",
             "고양이 강아지 싫다",
             "강아지 고양이 좋다"]
